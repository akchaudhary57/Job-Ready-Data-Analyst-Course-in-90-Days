# %% [markdown]
# ## Missing value

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/class_grades.csv')
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00       NaN  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
df[df.isnull()]
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0      NaN         NaN       NaN      NaN       NaN    NaN
# 1      NaN         NaN       NaN      NaN       NaN    NaN
# 2      NaN         NaN       NaN      NaN       NaN    NaN
# 3      NaN         NaN       NaN      NaN       NaN    NaN
# 4      NaN         NaN       NaN      NaN       NaN    NaN
# ..     ...         ...       ...      ...       ...    ...
# 94     NaN         NaN       NaN      NaN       NaN    NaN
# 95     NaN         NaN       NaN      NaN       NaN    NaN
# 96     NaN         NaN       NaN      NaN       NaN    NaN
# 97     NaN         NaN       NaN      NaN       NaN    NaN
# 98     NaN         NaN       NaN      NaN       NaN    NaN
#
# [99 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Prefix        0
# Assignment    7
# Tutorial      3
# Midterm       3
# TakeHome      5
# Final         3
# dtype: int64

# %%
df.dropna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %%
df.fillna(0, inplace=True)
df.head(10)
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00
# 7       7       72.85     86.85    60.00      0.00  56.11
# 8       8       84.26     93.10    47.50     18.52  50.83
# 9       7       90.10     97.55    51.25     88.89  63.61

# %%
log = pd.read_csv('datasets/log.csv')

# %%
log
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
log= log.set_index('time')
log= log.sort_index()

# %%
log.head(10)
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN

# %%
log = log.reset_index()
log = log.set_index(['time','user'])

# %%
# it fills the record based on previous value
log = log.fillna(method = 'ffill')
log
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0
# 1469974514 cheryl     intro.html                  8   False    10.0
# 1469974524 sue     advanced.html                 25   False    10.0
# 1469974544 cheryl     intro.html                  9   False    10.0
# 1469974554 sue     advanced.html                 26   False    10.0
# 1469974574 cheryl     intro.html                 10   False    10.0
# 1469974604 cheryl     intro.html                 11   False    10.0
# 1469974624 sue     advanced.html                 27   False    10.0
# 1469974634 cheryl     intro.html                 12   False    10.0
# ...

# %%
df = pd.DataFrame({'A': [1, 1, 2, 3, 4],
                   'B': [3, 6, 3, 8, 9],
                   'C': ['a', 'b', 'c', 'd', 'e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
df.replace(1,100)

# %%
df.replace([1,3],[100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
log
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0
# 1469974514 cheryl     intro.html                  8   False    10.0
# 1469974524 sue     advanced.html                 25   False    10.0
# 1469974544 cheryl     intro.html                  9   False    10.0
# 1469974554 sue     advanced.html                 26   False    10.0
# 1469974574 cheryl     intro.html                 10   False    10.0
# 1469974604 cheryl     intro.html                 11   False    10.0
# 1469974624 sue     advanced.html                 27   False    10.0
# 1469974634 cheryl     intro.html                 12   False    10.0
# ...

# %%
import re 

data = 'intro.html'

re.findall('[\w]+[.]html$',data)
# Out:
# ['intro.html']

# %%
log.replace(to_replace = '[\w]+[.]html$', value = "Webpage", regex = True)
# Out:
#                      video  playback position  paused  volume
# time       user
# 1469974424 cheryl  Webpage                  5   False    10.0
#            sue     Webpage                 23   False    10.0
# 1469974454 cheryl  Webpage                  6   False    10.0
#            sue     Webpage                 24   False    10.0
# 1469974484 cheryl  Webpage                  7   False    10.0
# 1469974514 cheryl  Webpage                  8   False    10.0
# 1469974524 sue     Webpage                 25   False    10.0
# 1469974544 cheryl  Webpage                  9   False    10.0
# 1469974554 sue     Webpage                 26   False    10.0
# 1469974574 cheryl  Webpage                 10   False    10.0
# 1469974604 cheryl  Webpage                 11   False    10.0
# 1469974624 sue     Webpage                 27   False    10.0
# 1469974634 cheryl  Webpage                 12   False    10.0
# 1469974654 sue     Webpage                 28   False     5.0
# ...

# %%
df = pd.read_csv("datasets/presidents.csv")

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
import re
name = 'George Washington'

re.findall('[ ].*',name)
# Out:
# [' Washington']

# %%
df['FirstName'] = df['President'].replace('[ ].*','',regex = True)

# %%
del df['FirstName']

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# ...

# %%
def splitname(row):
    row['FirstName'] = row['President'].split(' ')[0]
    row['LastName'] = row['President'].split(' ')[-1]
    return row

# %%
df = df.apply(splitname,axis = 1)
df.head(20)
# Out:
#      #            President             Born       Age atstart of presidency  \
# 0    1    George Washington  Feb 22, 1732[a]   57 years, 67 daysApr 30, 1789
# 1    2           John Adams  Oct 30, 1735[a]   61 years, 125 daysMar 4, 1797
# 2    3     Thomas Jefferson  Apr 13, 1743[a]   57 years, 325 daysMar 4, 1801
# 3    4        James Madison  Mar 16, 1751[a]   57 years, 353 daysMar 4, 1809
# 4    5         James Monroe     Apr 28, 1758   58 years, 310 daysMar 4, 1817
# 5    6    John Quincy Adams     Jul 11, 1767   57 years, 236 daysMar 4, 1825
# 6    7       Andrew Jackson     Mar 15, 1767   61 years, 354 daysMar 4, 1829
# 7    8     Martin Van Buren      Dec 5, 1782    54 years, 89 daysMar 4, 1837
# 8    9  William H. Harrison      Feb 9, 1773    68 years, 23 daysMar 4, 1841
# 9   10           John Tyler     Mar 29, 1790     51 years, 6 daysApr 4, 1841
# 10  11        James K. Polk      Nov 2, 1795   49 years, 122 daysMar 4, 1845
# ...

# %%
del df['FirstName']
del df['LastName']

# %%
#fullname = 'George Washington'

#re.findall('([\w]+)(?:\s)([\w]+)',fullname)

pattern = '([\w]+)(?:\s)([\w].*)'
df["President"].str.extract(pattern).head()
# Out:
#         0           1
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
fullname = 'James H Garfield'

re.findall('([\w]+)(?:.* )([\w]+)',fullname)
# Out:
# [('James', 'Garfield')]

# %%
pattern = '(?P<First>[\w]+)(?:.* )(?P<Last>[\w]+)'
names  = df["President"].str.extract(pattern)

# %%
df['First'] = names['First']
df['Last'] = names['Last']

# %%
df
# Out:
#      #              President             Born  \
# 0    1      George Washington  Feb 22, 1732[a]
# 1    2             John Adams  Oct 30, 1735[a]
# 2    3       Thomas Jefferson  Apr 13, 1743[a]
# 3    4          James Madison  Mar 16, 1751[a]
# 4    5           James Monroe     Apr 28, 1758
# 5    6      John Quincy Adams     Jul 11, 1767
# 6    7         Andrew Jackson     Mar 15, 1767
# 7    8       Martin Van Buren      Dec 5, 1782
# 8    9    William H. Harrison      Feb 9, 1773
# 9   10             John Tyler     Mar 29, 1790
# 10  11          James K. Polk      Nov 2, 1795
# 11  12         Zachary Taylor     Nov 24, 1784
# 12  13       Millard Fillmore      Jan 7, 1800
# 13  14        Franklin Pierce     Nov 23, 1804
# 14  15         James Buchanan     Apr 23, 1791
# 15  16        Abraham Lincoln     Feb 12, 1809
# 16  17         Andrew Johnson     Dec 29, 1808
# 17  18       Ulysses S. Grant     Apr 27, 1822
# 18  19    Rutherford B. Hayes      Oct 4, 1822
# ...

# %%
born = 'Feb 22, 1732[a]'

re.findall('([\w]{3} [\w]{2}, [\w]{4})',born)
# Out:
# ['Feb 22, 1732']

# %%
pattern = '([\w]{3} [\w]{2}, [\w]{4})'
df['Born'] = df['Born'].str.extract(pattern)

# %%
df['Born'] = pd.to_datetime(df['Born'])

# %%
df
# Out:
#      #              President       Born       Age atstart of presidency  \
# 0    1      George Washington 1732-02-22   57 years, 67 daysApr 30, 1789
# 1    2             John Adams 1735-10-30   61 years, 125 daysMar 4, 1797
# 2    3       Thomas Jefferson 1743-04-13   57 years, 325 daysMar 4, 1801
# 3    4          James Madison 1751-03-16   57 years, 353 daysMar 4, 1809
# 4    5           James Monroe 1758-04-28   58 years, 310 daysMar 4, 1817
# 5    6      John Quincy Adams 1767-07-11   57 years, 236 daysMar 4, 1825
# 6    7         Andrew Jackson 1767-03-15   61 years, 354 daysMar 4, 1829
# 7    8       Martin Van Buren        NaT    54 years, 89 daysMar 4, 1837
# 8    9    William H. Harrison        NaT    68 years, 23 daysMar 4, 1841
# 9   10             John Tyler 1790-03-29     51 years, 6 daysApr 4, 1841
# 10  11          James K. Polk        NaT   49 years, 122 daysMar 4, 1845
# 11  12         Zachary Taylor 1784-11-24   64 years, 100 daysMar 4, 1849
# ...

# %% [markdown]
# ![Venn Diagram](merging1.png)
# ![Union](merging2.png)
# ![Intersection](merging3.png)

# %%
# First we create two DataFrames, staff and students.
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
# And lets index these staff by name
staff_df = staff_df.set_index('Name')
# Now we'll create a student dataframe
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
# And we'll index this by name too
student_df = student_df.set_index('Name')

# And lets just print out the dataframes
print(staff_df.head())
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how = 'outer', left_index = True, right_index = True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how = 'inner', left_index = True, right_index = True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how = 'left', left_index = True, right_index = True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how = 'right', left_index = True, right_index = True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()

# %%
pd.merge(staff_df,student_df, how ='right' , on ='Name')
# Out:
#     Name            Role       School
# 0  Sally  Course liasion  Engineering
# 1  James          Grader     Business
# 2   Mike             NaN          Law

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 
                          'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 
                          'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 
                          'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 
                            'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 
                            'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 
                            'Location': '512 Wilson Crescent'}])

# %%
pd.merge(staff_df,student_df, how ='right' , on ='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 1  James          Grader  Washington Avenue     Business  1024 Billiard Avenue
# 2   Mike             NaN                NaN          Law  Fraternity House #22

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 
                          'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 
                          'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 
                          'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 
                            'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 
                            'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 
                            'School': 'Engineering'}])


pd.merge(staff_df, student_df, how='inner', on=['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %%
frames = [staff_df,student_df]
pd.concat(frames)
# Out:
#   First Name   Last Name            Role       School
# 0      Kelly  Desjardins  Director of HR          NaN
# 1      Sally      Brooks  Course liasion          NaN
# 2      James       Wilde          Grader          NaN
# 0      James     Hammond             NaN     Business
# 1       Mike       Smith             NaN          Law
# 2      Sally      Brooks             NaN  Engineering

# %%
frames = [staff_df,student_df]
pd.concat(frames,keys =['Staff','Student'])
# Out:
#           First Name   Last Name            Role       School
# Staff   0      Kelly  Desjardins  Director of HR          NaN
#         1      Sally      Brooks  Course liasion          NaN
#         2      James       Wilde          Grader          NaN
# Student 0      James     Hammond             NaN     Business
#         1       Mike       Smith             NaN          Law
#         2      Sally      Brooks             NaN  Engineering

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datasets/census.csv")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County           54571.0              54571.0
# ...

# %%
df = df[df['SUMLEV']==50]
df.set_index(['STNAME','CTYNAME'], inplace=True)
df.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County             54571                54571
# ...

# %%
df = pd.read_csv("datasets/census.csv")
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %%
df.apply(min_max, axis='columns').head()
# Out:
#                              min       max
# STNAME  CTYNAME
# Alabama Autauga County   54660.0   55347.0
#         Baldwin County  183193.0  203709.0
#         Barbour County   26489.0   27341.0
#         Bibb County      22512.0   22861.0
#         Blount County    57373.0   57776.0

# %%
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]

    row['max'] = np.max(data)

    row['min'] = np.min(data)
    return row

df.apply(min_max, axis='columns')
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# ...

# %%
rows = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013','POPESTIMATE2014', 
        'POPESTIMATE2015']
df.apply(lambda x: np.max(x[rows]), axis=1).head()
# Out:
# STNAME   CTYNAME
# Alabama  Autauga County     55347.0
#          Baldwin County    203709.0
#          Barbour County     27341.0
#          Bibb County        22861.0
#          Blount County      57776.0
# dtype: float64

# %%
def get_state_region(x):
    northeast = ['Connecticut', 'Maine', 'Massachusetts', 'New Hampshire', 
                 'Rhode Island','Vermont','New York','New Jersey','Pennsylvania']
    midwest = ['Illinois','Indiana','Michigan','Ohio','Wisconsin','Iowa',
               'Kansas','Minnesota','Missouri','Nebraska','North Dakota',
               'South Dakota']
    south = ['Delaware','Florida','Georgia','Maryland','North Carolina',
             'South Carolina','Virginia','District of Columbia','West Virginia',
             'Alabama','Kentucky','Mississippi','Tennessee','Arkansas',
             'Louisiana','Oklahoma','Texas']
    west = ['Arizona','Colorado','Idaho','Montana','Nevada','New Mexico','Utah',
            'Wyoming','Alaska','California','Hawaii','Oregon','Washington']
    
    if x in northeast:
        return "Northeast"
    elif x in midwest:
        return "Midwest"
    elif x in south:
        return "South"
    else:
        return "West"

# %%
df['state_region'] = df['STNAME'].apply(get_state_region)

# %%
df['state_region'] = df['STNAME'].apply(lambda x: get_state_region(x))

# %%
df[['state_region','STNAME']]
# Out:
#      state_region   STNAME
# 0           South  Alabama
# 1           South  Alabama
# 2           South  Alabama
# 3           South  Alabama
# 4           South  Alabama
# ...           ...      ...
# 3188         West  Wyoming
# 3189         West  Wyoming
# 3190         West  Wyoming
# 3191         West  Wyoming
# 3192         West  Wyoming
#
# [3193 rows x 2 columns]

# %% [markdown]
# ### Groupby Aggregation

# %%
df.columns
df['DiffPOSESTIMATE2010_2011'] = df['POPESTIMATE2011']-df['POPESTIMATE2010']

# %%
df[['SUMLEV','CENSUS2010POP']]
df.groupby('SUMLEV').agg({'DiffPOSESTIMATE2010_2011':np.average})
#df.groupby('SUMLEV').agg({'CENSUS2010POP':np.nanmean})
# Out:
#         DiffPOSESTIMATE2010_2011
# SUMLEV
# 40                  46509.686275
# 50                    754.931254

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2012  \
# 0        4779736            4780127          4785161  ...         -0.193196
# 1          54571              54571            54660  ...         -2.915927
# 2         182265             182265           183193  ...         17.647293
# 3          27457              27457            27341  ...         -2.500690
# 4          22915              22919            22861  ...         -5.068871
#
#    RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  \
# ...

# %%
df.groupby('SUMLEV').agg({'DiffPOSESTIMATE2010_2011':(np.average,np.nanstd),'ESTIMATESBASE2010':np.nanmean})
# Out:
#        DiffPOSESTIMATE2010_2011               ESTIMATESBASE2010
#                         average        nanstd           nanmean
# SUMLEV
# 40                 46509.686275  81686.086704      6.054080e+06
# 50                   754.931254   3847.284814      9.826802e+04

# %% [markdown]
# ## Transformation

# %%
cols=['SUMLEV','DiffPOSESTIMATE2010_2011']
# Now lets transform it, I'll store this in its own dataframe
transform_df=df[cols].groupby('SUMLEV').transform(np.nanmean)
transform_df.head()
# Out:
#    DiffPOSESTIMATE2010_2011
# 0              46509.686275
# 1                754.931254
# 2                754.931254
# 3                754.931254
# 4                754.931254

# %%
transform_df.rename({'DiffPOSESTIMATE2010_2011':'Mean_DiffPOSESTIMATE2010_2011'}, axis='columns', inplace=True)
df=df.merge(transform_df, left_index=True, right_index=True)
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2013  \
# 0        4779736            4780127          4785161  ...          0.381066
# 1          54571              54571            54660  ...         -3.012349
# 2         182265             182265           183193  ...         21.845705
# 3          27457              27457            27341  ...         -7.056824
# 4          22915              22919            22861  ...         -6.201001
#
#    RDOMESTICMIG2014  RDOMESTICMIG2015  RNETMIG2011  RNETMIG2012  RNETMIG2013  \
# ...

# %% [markdown]
# ## Filter

# %%
df.groupby('SUMLEV').filter(lambda x: np.nanmean(x['DiffPOSESTIMATE2010_2011'])>760)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY                STNAME  \
# 0         40       3         6      1       0               Alabama
# 68        40       4         9      2       0                Alaska
# 98        40       4         8      4       0               Arizona
# 114       40       3         7      5       0              Arkansas
# 190       40       4         9      6       0            California
# 249       40       4         8      8       0              Colorado
# 314       40       1         1      9       0           Connecticut
# 323       40       3         5     10       0              Delaware
# 327       40       3         5     11       0  District of Columbia
# 329       40       3         5     12       0               Florida
# 397       40       3         5     13       0               Georgia
# 557       40       4         9     15       0                Hawaii
# 563       40       4         8     16       0                 Idaho
# ...
