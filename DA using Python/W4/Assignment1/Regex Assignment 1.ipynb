# %% [markdown]
# #### Q1
#
# s = 'ACBCAC'
#
# For the given string, write regular expressions that can be used to check if the string starts with 'AC'?

# %% [markdown]
# #### 2) Write a regular expression to extract numbering from the text. The output should be ['(1)', '(2)', '(3)', '(4)']
#
# From the given text
# text=r'''Everyone has the following fundamental freedoms:
#
# (1) freedom of conscience and religion.
#
# (2) freedom of thought, belief, opinion, and expression, including freedom of the press and other media of communication.
#
# (3) freedom of peaceful assembly; and
#
# (4) freedom of association.
# '''

# %% [markdown]
# #### 3) Write a regular expression to extract domain names (e.g. google.com, www.yahoo.com) from the following sentence?
#
# 'I usually visit to https://google.com but I never browse https://www.yahoo.com if I have to search anything’

# %% [markdown]
# #### 4) Write a regular expression to extract phone number from the following sentence?
#
# Office of Research Administration: (734) 647-6333 | 4325 North Quad
#
# Office of the Dean: (734) 647-3576 | 4322 North Quad

# %%
from IPython.display import Image
Image("NA1.png")

# %% [markdown]
# #### 5) Given the 6x6 NumPy array r shown above, write an array that would slice the shaded elements?

# %% [markdown]
# #### 7)
#
# String = 'bat, lat, mat, bet, let, met, bit, lit, mit, bot, lot, mot'
#
# #### Write a regular expression that would yield a result ['bat','bot']?

# %% [markdown]
# #### 8)
#
# #### Find a list of all of the names in the following string using regex.

# %%
simple_string = """John is 15 years old, and her sister Mary is 2 years old. 
    Ruth and Peter, their parents, have 7 kids."""
